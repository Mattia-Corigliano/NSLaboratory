# %% [markdown]
# # Numerical Simulation Laboratory
# ## Exercise 1

# %% [markdown]
# ### Exercise 1.1. (c++ random number generator)

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("/home/mattia/Scrivania/Numerical_Simulation_Laboratory/Exercises/EX1_bis/output.txt").T
data2 = np.loadtxt("/home/mattia/Scrivania/Numerical_Simulation_Laboratory/Exercises/EX1_bis/output2.txt").T
data3 = np.loadtxt("/home/mattia/Scrivania/Numerical_Simulation_Laboratory/Exercises/EX1_bis/output3.txt").T

plt.errorbar(data[0],data[1]-0.5,yerr=data[2], fmt = "--", color = 'k', ecolor = 'lightgrey', capsize = 2)
plt.title("Mean as a function of \nthe number of throws", size = 20)
plt.xlabel('#throws', size = 16)
plt.ylabel('<r>-1/2', size = 16)
plt.grid(True)
plt.show()

plt.errorbar(data2[0],data2[1]-1/12.,yerr=data2[2], color = 'k', ecolor = 'lightgrey', capsize = 2)
plt.title("Mean of the variance as a function of \nthe number of throws", size = 20)
plt.xlabel('#throws', size=16)
plt.ylabel('<(r-0.5)^2>-1/12', size=16)
plt.grid(True)
plt.show()

plt.plot(data3[0],data3[1]-1., 'ok')
plt.title("chi-quadro in the subintervals", size = 20)
plt.xlabel('subinterval', size=16)
plt.ylabel('chi-quadro(i)-1', size=16)
plt.grid(True)
plt.show()

print("chi quadro = ", data3[1].sum())
# Out:
# chi quadro =  98.69

# %% [markdown]
# ### Exercise 1.1. (Galli random number generator)

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.loadtxt("output.txt").T
data2 = np.loadtxt("output2.txt").T
data3 = np.loadtxt("output3.txt").T

plt.errorbar(data[0],data[1]-0.5,yerr=data[2], fmt = "--", color = 'k', ecolor = 'lightgrey', capsize = 2)
plt.title("Mean as a function of \nthe number of throws", size = 20)
plt.xlabel('#throws', size = 16)
plt.ylabel('<r>-1/2', size = 16)
plt.grid(True)
plt.show()

plt.errorbar(data2[0],data2[1]-1/12.,yerr=data2[2], color = 'k', ecolor = 'lightgrey', capsize = 2)
plt.title("Mean of the variance as a function of \nthe number of throws", size = 20)
plt.xlabel('#throws', size=16)
plt.ylabel('<(r-0.5)^2>-1/12', size=16)
plt.grid(True)
plt.show()

plt.plot(data3[0],data3[1]-1., 'ok')
plt.title("chi-quadro in the subintervals", size = 20)
plt.xlabel('subinterval', size=16)
plt.ylabel('chi-quadro(i)-1', size=16)
plt.grid(True)
plt.show()

print("chi quadro = ", data3[1].sum())
# Out:
# chi quadro =  115.91

# %% [markdown]
# ### Exercise 2

# %%
data4 = np.loadtxt("output4.txt").T

labels = [1, 2, 10, 100]
bins = [6, 10, 20, 20]

for i in range (4) :
    plt.subplot(1, 4, i+1); plt.hist(data4[i], bins =bins[i], color = "lightgrey",
                                     density=True, label = "N = {}".format(labels[i]))
    plt.legend()
    plt.xlabel("n", size=16)
    plt.grid(True)
fig = plt.gcf()
ax = plt.gca()
fig.set_size_inches(16, 4)
fig.text(0.35, 0.92, "Histograms of S_N for the standard dice", size = 16)
fig.text(0.07, 0.42, "density", size = 16, rotation="vertical")
plt.show()

for i in range (4) :
    plt.subplot(1, 4, i+1); plt.hist(data4[i+4], bins =bins[i], color = "lightgrey",
                                     density=True, label = "N = {}".format(labels[i]))
    plt.legend()
    plt.xlabel("n", size=16)
    plt.grid(True)
fig = plt.gcf()
ax = plt.gca()
fig.set_size_inches(16, 4)
fig.text(0.35, 0.92, "Histograms of S_N for the exponential dice", size = 16)
fig.text(0.07, 0.42, "density", size = 16, rotation="vertical")
plt.show()

for i in range (4) :
    plt.subplot(1, 4, i+1); plt.hist(data4[i+8], bins =bins[i], color = "lightgrey",
                                     density=True, label = "N = {}".format(labels[i]))
    plt.legend()
    plt.xlabel("n", size=16)
    plt.grid(True)
fig = plt.gcf()
ax = plt.gca()
fig.set_size_inches(16, 4)
fig.text(0.35, 0.92, "Histograms of S_N for the lorenzian dice", size = 16)
fig.text(0.07, 0.42, "density", size = 16, rotation="vertical")
plt.show()

print(data4[8].min())
# Out:
# -27737.0

# %% [markdown]
# ### Exercise 3

# %%
data5 = np.loadtxt("output5.txt").T

plt.errorbar(data5[0],data5[1],yerr=data5[2], fmt = "--", color = 'k', ecolor = 'lightgrey', capsize = 2)
plt.title("Estimates of pi via Buffon's Experiment", size = 20)
plt.xlabel('#throws', size = 16)
plt.ylabel('estimated pi', size = 16)
plt.semilogx()
plt.grid(True)
plt.show()

# %% [markdown]
# The number of blocks has to be chosen so that the estimates of pi within each block are fairly good.
# Otherwise, when we mean over this estimates we find a robust estimate (low error) but inaccurate.

# %% [markdown]
# It is important to note that altough the inclination angle of the needle $\theta$ is uniformly distributed in $[0, \pi]$ its vertical lenght $y = L\cos \theta$ is not.
#
# Indeed, we have: \begin{align*}
# p(y) \Delta y &= \int_{y < f(\theta) < y + \Delta y} dx \ p(x) = \int dx \ p(x) \left[ \theta(y+\Delta y-f(\theta))-\theta(y-f(x)) \right] = \int dx \ p(x) \delta(y-f(x)) \Delta y
# \end{align*}
#
# and, using the property $\delta(y-f(x)) = \delta(y-x_0)/|f'(x_0)|$, with $x_0 = \arccos y/L$
#
# \begin{align*} p(y)= \frac{1}{\pi L} \frac{1}{\sin{\arccos(\frac{y}{L})}}\end{align*}

# %%
# It is important to note that theta uniform in 0, pi doesn't imply Lcostheta uniform in -L L

theta = np.random.uniform(0., np.pi, 100000)
x = np.linspace(-0.99, 0.99, num = 101)
L =np.cos(theta)
plt.hist(theta, density=True)
plt.show()
plt.hist(L,bins = 20, density=True, color = "lightgrey")
plt.plot(x, 1/(np.pi*1.)*1./np.sin(np.arccos(x)), "r-", lw =3 )
plt.show()
