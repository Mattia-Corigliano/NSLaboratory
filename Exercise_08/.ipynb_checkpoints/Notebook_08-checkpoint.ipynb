# %% [markdown]
# # Numerical Simulation Laboratory
#                                         Department of Physics, University of Milan(It)
#                                         Spring 2020
#                                                                      Mattia Corigliano
# ## 8<sup>th </sup> Computational Exercise

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import simps

##  setting the Layout
import matplotlib as mpl
## LINES
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.linestyle'] = '-'
## AXES
mpl.rcParams['axes.linewidth'] = 1 ## edge linewidth
mpl.rcParams['axes.grid'] = True ## display grid or not
mpl.rcParams['axes.titlesize'] = 16 ## fontsize of the axes title
#mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.labelsize'] = 14  ## fontsize of the x any y labels
mpl.rcParams['axes.formatter.limits'] = [-2,6] # use scientific notation if log10
mpl.rcParams['axes.formatter.use_mathtext'] = True # When True, use mathtext for scientific
mpl.rcParams['legend.fontsize'] = 12
## TICKS
mpl.rcParams['xtick.labelsize'] = 12 ## fontsize of the tick labels
mpl.rcParams['ytick.labelsize'] = 12 
mpl.rcParams['xtick.minor.visible'] = True ## visibility of minor ticks on x-axis
mpl.rcParams['ytick.minor.visible'] = True
## FIGURE
mpl.rcParams['figure.titleweight'] = 'bold' ## weight of the figure title
mpl.rcParams['figure.subplot.wspace'] = 0.4
mpl.rcParams['figure.subplot.hspace'] = 0.4
## ERRORBARS
mpl.rcParams['errorbar.capsize'] = 2  ## length of end cap on error bars in pixels

# %% [markdown]
# ## Exercise 8.1
# ### Preliminary analysis: finding optimal delta value for Metropolis

# %%
optimal_delta = np.loadtxt("optimal_delta_value.txt").T
sampled_x = np.loadtxt("trial_x.txt").T
trial_Egs = np.loadtxt("trial_Egs.txt").T

fig = plt.figure(figsize=(8, 3), dpi=120)
fig.suptitle("Preliminary analysis: \nfindind optimal delta value for metropolis \n$\mu=1, \ \sigma = 0.5, \ \Delta_{opt.} = 1.18794$", y=1.1)
plt.subplot(1, 2, 1); plt.plot(optimal_delta[0], optimal_delta[1], 'b-', lw = 2)
plt.xlabel("delta")
plt.ylabel("$|f_{acc}-0.5|$")
plt.grid(True)
plt.xlim(0, 5)
plt.semilogy()
plt.subplot(1, 2, 2); plt.hist(sampled_x[1], bins = 20, density = True)
plt.subplots_adjust(wspace = 0.4)
plt.grid(True)
plt.show()

# <GS|H|GS> trial
fig = plt.figure(figsize=(4, 3), dpi=120)
plt.title("Trial $E_{GS}$")
plt.errorbar(trial_Egs[0], trial_Egs[1], yerr=trial_Egs[2], color='b', ecolor='gray')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 8.2

# %%
opt_x = np.loadtxt("optimized_x.txt").T
opt_Egs = np.loadtxt("optimized_Egs.txt").T

fig = plt.figure(figsize=(12, 5), dpi=120)
plt.suptitle("VMC calculation")
plt.subplot(1, 2, 1);
plt.errorbar(opt_Egs[0], opt_Egs[1], yerr=opt_Egs[2], color='b', ecolor='gray')
plt.title("opt $E_{GS}$")
plt.grid(True)

plt.subplot(1, 2, 2);
plt.hist(opt_x[1], bins = 120, density=True, color = 'b')
plt.title("$|\psi_{GS}(x)|^2$")
plt.grid(True)


def Vpot(x):
    return (x**2 - 2.5)*x**2

hbar = 1
m = 1
a = 6
N = 1000 # number of iterations

# Step sizes
x1 = np.linspace(-a/2, a/2, N)
dx = x1[1] - x1[0] # the step size
V = Vpot(x1)

# The central differences method: f" = (f_1 - 2*f_0 + f_-1)/dx^2

CDiff = np.diag(np.ones(N-1),-1)-2*np.diag(np.ones(N),0)+np.diag(np.ones(N-1),1)
# np.diag(np.array,k) construct a "diagonal" matrix using the np.array
# The default is k=0. Use k>0 for diagonals above the main diagonal, 
# and k<0 for diagonals below the main diagonal

# Hamiltonian matrix
H = (-(hbar**2)*CDiff)/(2*m*dx**2) + np.diag(V)

# Compute eigenvectors and their eigenvalues
E,psi = np.linalg.eigh(H)

# Take the transpose & normalize
psi = np.transpose(psi)
psi = psi/np.sqrt(dx)

plt.plot(x1, (psi[0])**2,label="Matrix")

#Import optimal mu and sigma 
#optimization ended with optimal values: mu = 0.795881 , sigma = 0.638836


mu = 0.795881
sigma =  0.638836

def Opt_Psi(x):
    return np.exp(-(x-mu)**2/(2*sigma**2))+np.exp(-(x+mu)**2/(2*sigma**2))

y = Opt_Psi(x1)*Opt_Psi(x1)
N=simps(y,x1)
plt.plot(x1, y/N , 'r-', lw=2, label="analytical")
plt.legend()

plt.show()

# %% [markdown]
# ### Exercise 8.3

# %%
const_kinetic_pigs = np.loadtxt("QMC_1D/Results/pigs/const_kinetic.dat").T
const_potential_pigs = np.loadtxt("QMC_1D/Results/pigs/const_potential.dat").T
kinetic_pigs = np.loadtxt("QMC_1D/Results/pigs/kinetic.dat").T
potential_pigs = np.loadtxt("QMC_1D/Results/pigs/potential.dat").T
kinetic_pigs2 = np.loadtxt("QMC_1D/Results/pigs/T=4kinetic.dat").T
potential_pigs2 = np.loadtxt("QMC_1D/Results/pigs/T=4potential.dat").T
kinetic_pigs3 = np.loadtxt("QMC_1D/Results/pigs/T=2kinetic.dat").T
potential_pigs3 = np.loadtxt("QMC_1D/Results/pigs/T=2potential.dat").T

# PIGS
#preparing for data blocking...
blocks = np.arange(1, 301, 1)
def error(ave2, ave, n):
    if n==0:
        return 0
    else:
        return np.sqrt((ave2-ave*ave)/k)

fig = plt.figure(figsize=(12, 4), dpi=120)
plt.subplot(1, 2, 1);

energy = np.zeros(len(blocks))
for k in range(len(blocks)):
    energy[k] = const_kinetic_pigs[1][k]+const_potential_pigs[1][k]
    
#performing data blocking
ave = np.zeros(len(blocks))
ave2 = np.zeros(len(blocks))
blocking_error = np.zeros(len(blocks))
 
for k in range(len(blocks)):
    for j in range(k+1):
        ave[k] = ave[k] + energy[j]/(k+1)
        ave2[k] = ave2[k] + energy[j]*energy[j]/(k+1)
    blocking_error[k] = error(ave2[k], ave[k], k) 
    
plt.errorbar(blocks, ave, yerr=blocking_error, color='b', ecolor='gray')
plt.grid(True)
plt.xlabel("# of blocks")
plt.ylabel("$E_{GS}$")
plt.title("$E_{GS}$ projecting $\Psi_T(x)=1$")

plt.subplot(1, 2, 2);
energy = np.zeros(len(blocks))
for k in range(len(blocks)):
    energy[k] = kinetic_pigs[1][k]+potential_pigs[1][k]
    
#performing data blocking
ave = np.zeros(len(blocks))
ave2 = np.zeros(len(blocks))
blocking_error = np.zeros(len(blocks))
 
for k in range(len(blocks)):
    for j in range(k+1):
        ave[k] = ave[k] + energy[j]/(k+1)
        ave2[k] = ave2[k] + energy[j]*energy[j]/(k+1)
    blocking_error[k] = error(ave2[k], ave[k], k) 
plt.errorbar(blocks, ave, yerr=blocking_error, color='b', ecolor='gray', capsize=2, label='T=8')
plt.grid(True)
plt.xlabel("# of blocks")
plt.ylabel("$E_{GS}$")
plt.title("$E_{GS}$ projecting $\Psi^{\mu, \sigma}_T(x)$")

energy = np.zeros(len(blocks))
for k in range(len(blocks)):
    energy[k] = kinetic_pigs2[1][k]+potential_pigs2[1][k]
    
#performing data blocking
ave = np.zeros(len(blocks))
ave2 = np.zeros(len(blocks))
blocking_error = np.zeros(len(blocks))
 
for k in range(len(blocks)):
    for j in range(k+1):
        ave[k] = ave[k] + energy[j]/(k+1)
        ave2[k] = ave2[k] + energy[j]*energy[j]/(k+1)
    blocking_error[k] = error(ave2[k], ave[k], k) 
plt.errorbar(blocks, ave, yerr=blocking_error, color='r', ecolor='lightgray', capsize=2, label='T=4')

energy = np.zeros(len(blocks))
for k in range(len(blocks)):
    energy[k] = kinetic_pigs3[1][k]+potential_pigs3[1][k]
    
#performing data blocking
ave = np.zeros(len(blocks))
ave2 = np.zeros(len(blocks))
blocking_error = np.zeros(len(blocks))
 
for k in range(len(blocks)):
    for j in range(k+1):
        ave[k] = ave[k] + energy[j]/(k+1)
        ave2[k] = ave2[k] + energy[j]*energy[j]/(k+1)
    blocking_error[k] = error(ave2[k], ave[k], k) 
plt.errorbar(blocks, ave, yerr=blocking_error, color='g', ecolor='lightgray', capsize=2, label='T=2')

plt.legend()
plt.show()

# %%
config = np.loadtxt("QMC_1D/Results/pimc/T=1.5probability.dat").T
config2 = np.loadtxt("QMC_1D/Results/pimc/T=2probability.dat").T
config3= np.loadtxt("QMC_1D/Results/pimc/T=4probability.dat").T
config4 = np.loadtxt("QMC_1D/Results/pimc/T=6probability.dat").T
config5 = np.loadtxt("QMC_1D/Results/pimc/T=8probability.dat").T
config6 = np.loadtxt("QMC_1D/Results/pimc/T=12probability.dat").T

plt.figure(figsize=(5,4), dpi=120)
plt.plot(config[0], config[1], label='T=1.5')
plt.plot(config2[0], config2[1], label='T=2')
plt.plot(config3[0], config3[1], label='T=4')
plt.plot(config4[0], config4[1], label='T=6')
plt.plot(config5[0], config5[1], label='T=8')
plt.plot(config6[0], config6[1], label='T=12')
plt.grid(True)
plt.xlabel("x")
plt.ylabel("$|\psi_{GS}(x)|^2$")
plt.legend()
plt.show()
